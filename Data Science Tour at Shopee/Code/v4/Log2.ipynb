# %%
from mains import GRU
from mains.GRU import main

# %%
config_dict = {
  "exp_name": "GRU",
  "num_epochs": 100,
  "num_iter_per_epoch": 100,
  "learning_rate": 0.01,
  "batch_size": 1024,

  "max_to_keep": 5,
  
  "num_steps": 2,
  "item_emb_size": 150,
  "user_emb_size": 150,
  "w2v_size": 1000,
  "num_item": 298000,
  "num_user": 25400,
  "num_layers": 1,
  "dropout": 0.0,
  "num_units_4emb": 300,
  

  "X_train_path": "/data/workspace/yeqi/projects/RNN4REC/GRU4REC/Processed Data/min_5_max_20/sliced data/X_train.npy",
  "X_test_path": "/data/workspace/yeqi/projects/RNN4REC/GRU4REC/Processed Data/min_5_max_20/X_test.npy"
  
}

GRU.main(config_dict)
# Out:
# Sample of training data:
#   userid pathid                              path length       Y
# 0  24054      7      [56972, 27704, 27703, 30325]      5   73218
# 1  19736     62    [117452, 173828, 135630, 8978]      5   19345
# 2  11445     52  [115639, 168292, 168295, 106023]      5   43727
# 3   7031    101   [28622, 264712, 247572, 199963]      5   32337
# 4  17479      7   [155881, 55112, 123739, 169190]      5  160357
# Here is the slicing table of the data:
#    length   count  start_index  end_index
# 0       5  204294            0     204294
# 1       6  131124       204294     335418
# 2      10  239681       335418     575099
# 3      20  104216       575099     679315
# shape of emb_top_state:  Tensor("rnn/while/Exit_3:0", shape=(?, 300), dtype=float32)
# shape of the logits:  (?, 298000)
#   0%|          | 0/100 [00:00<?, ?it/s]
# Sample of training data:
#   userid pathid                              path length       Y
# 0   3810     20  [206023, 234726, 160147, 208956]      5  151959
# 1  11914    200   [118534, 175612, 187618, 60579]      5  231929
# 2   3929     16  [152449, 249690, 241665, 123236]      5  144114
# 3   8110      7   [277606, 208204, 275379, 80837]      5    1868
# 4   7183      8  [280544, 280548, 210455, 280584]      5  243689
# Here is the slicing table of the test data:
#    length  count  start_index  end_index
# 0       5   5580            0       5580
# 1       6   3244         5580       8824
# 2      10   5035         8824      13859
# 3      20   2293        13859      16152
# 100%|██████████| 100/100 [01:33<00:00,  1.08it/s]
# Loss:  9.9222145 Accuracy:  0.31373048
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.02
# accuray of a test batch: 0.0
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.0
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.0
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.0
# accuray of a test batch: 0.02
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.0
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.02
# accuray of a test batch: 0.015
# accuray of a test batch: 0.0
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.0
# accuray of a test batch: 0.015
# accuray of a test batch: 0.0
# accuray of a test batch: 0.0
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.0
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.0
# accuray of a test batch: 0.005
# accuray of a test batch: 0.0
# accuray of a test batch: 0.005
# accuray of a test batch: 0.0
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.0
# accuray of a test batch: 0.005
# accuray of a test batch: 0.0
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.0
# accuray of a test batch: 0.0
# accuray of a test batch: 0.0
# accuray of a test batch: 0.015
# accuray of a test batch: 0.0
# accuray of a test batch: 0.0
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.0
# accuray of a test batch: 0.0
# Test loss:  12.918142971513058 Test accuracy:  0.0077389795257036
# Saving model...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Model saved
# 100%|██████████| 100/100 [01:32<00:00,  1.09it/s]
# Loss:  7.1233153 Accuracy:  0.52601564
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.02
# accuray of a test batch: 0.0
# accuray of a test batch: 0.0
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.0
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.0
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.02
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.0
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.0
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.025
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.03
# accuray of a test batch: 0.005
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.015
# accuray of a test batch: 0.03
# accuray of a test batch: 0.03
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.0
# accuray of a test batch: 0.01
# accuray of a test batch: 0.02
# accuray of a test batch: 0.015
# accuray of a test batch: 0.03
# accuray of a test batch: 0.02
# accuray of a test batch: 0.02
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# Test loss:  13.088817482126887 Test accuracy:  0.012630014654552013
# Saving model...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Model saved
# 100%|██████████| 100/100 [01:31<00:00,  1.08it/s]
# Loss:  6.3477263 Accuracy:  0.5851855
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.02
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.025
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.03
# accuray of a test batch: 0.02
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.03
# accuray of a test batch: 0.02
# accuray of a test batch: 0.0
# accuray of a test batch: 0.0
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.0
# accuray of a test batch: 0.025
# accuray of a test batch: 0.005
# accuray of a test batch: 0.0
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.035
# accuray of a test batch: 0.0
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.02
# accuray of a test batch: 0.025
# accuray of a test batch: 0.02
# accuray of a test batch: 0.025
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.0
# accuray of a test batch: 0.0
# Test loss:  13.388513587027743 Test accuracy:  0.011267954254776162
# Saving model...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Model saved
# 100%|██████████| 100/100 [01:30<00:00,  1.11it/s]
# Loss:  5.812837 Accuracy:  0.62285155
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.02
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.0
# accuray of a test batch: 0.015
# accuray of a test batch: 0.0
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.03
# accuray of a test batch: 0.025
# accuray of a test batch: 0.01
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.03
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.015
# accuray of a test batch: 0.0
# accuray of a test batch: 0.005
# accuray of a test batch: 0.02
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.0
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.02
# accuray of a test batch: 0.02
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.03
# accuray of a test batch: 0.015
# accuray of a test batch: 0.03
# accuray of a test batch: 0.02
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.035
# accuray of a test batch: 0.035
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.02
# Test loss:  13.519596212686082 Test accuracy:  0.01318722116459233
# Saving model...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Model saved
# 100%|██████████| 100/100 [01:31<00:00,  1.09it/s]
# Loss:  5.413738 Accuracy:  0.6534668
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.02
# accuray of a test batch: 0.035
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.025
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.0
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.02
# accuray of a test batch: 0.02
# accuray of a test batch: 0.02
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.0
# accuray of a test batch: 0.015
# accuray of a test batch: 0.02
# accuray of a test batch: 0.025
# accuray of a test batch: 0.0
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.02
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.0
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.025
# accuray of a test batch: 0.0
# accuray of a test batch: 0.02
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.02
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.02
# accuray of a test batch: 0.035
# accuray of a test batch: 0.02
# accuray of a test batch: 0.015
# accuray of a test batch: 0.03
# accuray of a test batch: 0.025
# accuray of a test batch: 0.025
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.045
# accuray of a test batch: 0.035
# accuray of a test batch: 0.02
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# Test loss:  13.990935671500726 Test accuracy:  0.013558692268212153
# Saving model...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Model saved
# 100%|██████████| 100/100 [01:29<00:00,  1.09it/s]
# Loss:  4.9969196 Accuracy:  0.6808106
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.02
# accuray of a test batch: 0.005
# accuray of a test batch: 0.0
# accuray of a test batch: 0.03
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.0
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.0
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.02
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.03
# accuray of a test batch: 0.015
# accuray of a test batch: 0.02
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.025
# accuray of a test batch: 0.01
# accuray of a test batch: 0.035
# accuray of a test batch: 0.015
# accuray of a test batch: 0.0
# accuray of a test batch: 0.005
# accuray of a test batch: 0.02
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.0
# accuray of a test batch: 0.025
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.03
# accuray of a test batch: 0.01
# accuray of a test batch: 0.02
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.0
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.02
# accuray of a test batch: 0.015
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.025
# accuray of a test batch: 0.03
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.045
# accuray of a test batch: 0.045
# accuray of a test batch: 0.025
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# Test loss:  14.082225610856788 Test accuracy:  0.013249133088164227
# Saving model...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Model saved
# 100%|██████████| 100/100 [01:30<00:00,  1.12it/s]
# Loss:  4.606628 Accuracy:  0.70890623
# accuray of a test batch: 0.02
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.025
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.025
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.02
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.025
# accuray of a test batch: 0.015
# accuray of a test batch: 0.03
# accuray of a test batch: 0.025
# accuray of a test batch: 0.025
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.03
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.0
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.02
# accuray of a test batch: 0.0
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.01
# accuray of a test batch: 0.02
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.03
# accuray of a test batch: 0.005
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.04
# accuray of a test batch: 0.03
# accuray of a test batch: 0.03
# accuray of a test batch: 0.035
# accuray of a test batch: 0.025
# accuray of a test batch: 0.025
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.03
# accuray of a test batch: 0.03
# accuray of a test batch: 0.02
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# Test loss:  14.252998342131434 Test accuracy:  0.015601782861072062
# Saving model...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Model saved
# 100%|██████████| 100/100 [01:30<00:00,  1.10it/s]
# Loss:  4.2425623 Accuracy:  0.7331543
# accuray of a test batch: 0.035
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.03
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.02
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.025
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.025
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.02
# accuray of a test batch: 0.02
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.025
# accuray of a test batch: 0.01
# accuray of a test batch: 0.03
# accuray of a test batch: 0.025
# accuray of a test batch: 0.025
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.0
# accuray of a test batch: 0.005
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.025
# accuray of a test batch: 0.015
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.025
# accuray of a test batch: 0.005
# accuray of a test batch: 0.02
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.035
# accuray of a test batch: 0.025
# accuray of a test batch: 0.015
# accuray of a test batch: 0.03
# accuray of a test batch: 0.015
# accuray of a test batch: 0.01
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.015
# accuray of a test batch: 0.025
# accuray of a test batch: 0.035
# accuray of a test batch: 0.04
# accuray of a test batch: 0.01
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# accuray of a test batch: 0.005
# accuray of a test batch: 0.01
# Test loss:  14.368321397860727 Test accuracy:  0.01504457635870051
# Saving model...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Model saved
#  96%|█████████▌| 96/100 [01:26<00:03,  1.10it/s]
